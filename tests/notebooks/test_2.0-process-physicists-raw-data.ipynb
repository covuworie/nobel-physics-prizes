# %%
import ipytest
import ipytest.magics
import pytest

from tests.src.data.test_dbpedia_utils import expected_albert_einstein_data
from tests.src.data.test_dbpedia_utils import expected_marie_curie_data
from tests.src.data.test_dbpedia_utils import expected_max_born_data
from tests.src.data.test_dbpedia_utils import expected_niels_bohr_data
from tests.src.data.test_dbpedia_utils import expected_david_carroll_data

ipytest.config.rewrite_asserts = True

__file__ = '../../tests/notebooks/test_2.0-process-physicists-raw-data.ipynb'

# %%
@pytest.fixture
def expected_homi_bhabha_data():
    return {'abstract': 'Not to be confused with Homi K. Bhabha. Homi Jehangir Bhabha '
            '(/ˈbɑːbɑː/;) (30 October 1909 – 24 January 1966) was an Indian '
            'nuclear physicist, founding director, and professor of physics '
            'at the Tata Institute of Fundamental Research. Colloquially '
            'known as "father of the Indian nuclear programme", Bhabha was '
            'the founding director of two well-known research institutions, '
            'namely the Tata Institute of Fundamental Research (TIFR) and the '
            'Trombay Atomic Energy Establishment (now named after him); both '
            'sites were the cornerstone of Indian development of nuclear '
            'weapons which Bhabha also supervised as its director.',
            'academicAdvisor': 'http://dbpedia.org/resource/Paul_Dirac',
            'almaMater': 'http://dbpedia.org/resource/Gonville_and_Caius_College,_Cambridge|http://dbpedia.org/resource/University_of_Mumbai',
            'birthDate': '1909-10-30',
            'birthPlace': 'http://dbpedia.org/resource/Bombay|http://dbpedia.org/resource/British_India|http://dbpedia.org/resource/Mumbai',
            'categories': 'http://dbpedia.org/resource/Category:1909_births|http://dbpedia.org/resource/Category:1966_deaths|http://dbpedia.org/resource/Category:Cathedral_and_John_Connon_School_alumni|http://dbpedia.org/resource/Category:Fellows_of_the_American_Academy_of_Arts_and_Sciences|http://dbpedia.org/resource/Category:Fellows_of_the_Indian_National_Science_Academy|http://dbpedia.org/resource/Category:Fellows_of_the_Royal_Society|http://dbpedia.org/resource/Category:Gujarati_people|http://dbpedia.org/resource/Category:Indian_Institute_of_Science_faculty|http://dbpedia.org/resource/Category:Indian_nuclear_physicists|http://dbpedia.org/resource/Category:Indian_physicists|http://dbpedia.org/resource/Category:Indian_Zoroastrians|http://dbpedia.org/resource/Category:Nuclear_history_of_India|http://dbpedia.org/resource/Category:Parsi_people|http://dbpedia.org/resource/Category:Recipients_of_the_Padma_Bhushan_in_science_&_engineering',
            'citizenship': 'India',
            'comment': 'Not to be confused with Homi K. Bhabha. Homi Jehangir Bhabha '
            '(/ˈbɑːbɑː/;) (30 October 1909 – 24 January 1966) was an Indian '
            'nuclear physicist, founding director, and professor of physics at '
            'the Tata Institute of Fundamental Research. Colloquially known as '
            '"father of the Indian nuclear programme", Bhabha was the founding '
            'director of two well-known research institutions, namely the Tata '
            'Institute of Fundamental Research (TIFR) and the Trombay Atomic '
            'Energy Establishment (now named after him); both sites were the '
            'cornerstone of Indian development of nuclear weapons which Bhabha '
            'also supervised as its director.',
            'deathDate': '1966-01-24',
            'deathPlace': 'http://dbpedia.org/resource/Bossons_Glacier|http://dbpedia.org/resource/Mont_Blanc',
            'description': '1909-1966, Indian nuclear physicist',
            'doctoralAdvisor': 'http://dbpedia.org/resource/Ralph_H._Fowler',
            'field': 'http://dbpedia.org/resource/Nuclear_Physics',
            'fullName': 'Homi J. Bhabha',
            'gender': 'male',
            'influenced': 'http://dbpedia.org/resource/Alladi_Ramakrishnan',
            'isPrimaryTopicOf': 'http://en.wikipedia.org/wiki/Homi_J._Bhabha',
            'knownFor': 'http://dbpedia.org/resource/Bhabha_Scattering|http://dbpedia.org/resource/Cosmic_radiation|http://dbpedia.org/resource/Indian_nuclear_programme|http://dbpedia.org/resource/Point_particle',
            'name': 'FRS|Homi Jehangir Bhabha',
            'nationality': 'http://dbpedia.org/resource/People_of_India',
            'residence': 'New Delhi, India',
            'resource': 'http://dbpedia.org/resource/Homi_J._Bhabha',
            'source': 'http://dbpedia.org/data/Homi_J._Bhabha.json',
            'thumbnail': 'http://commons.wikimedia.org/wiki/Special:FilePath/Homi_Jehangir_Bhabha_1960s.jpg?width=300',
            'wasDerivedFrom': 'http://en.wikipedia.org/wiki/Homi_J._Bhabha?oldid=744975270',
            'wikiPageID': 1245965,
            'wikiPageRevisionID': 744975270,
            'workplaces': 'http://dbpedia.org/resource/Atomic_Energy_Commission_of_India|http://dbpedia.org/resource/Bhabha_Atomic_Research_Centre|http://dbpedia.org/resource/Cavendish_Laboratory|http://dbpedia.org/resource/Indian_Institute_of_Science|http://dbpedia.org/resource/Tata_Institute_of_Fundamental_Research'
            }

# %%
@pytest.fixture
def expected_yuri_orlov_data():
    return {'abstract': 'Yuri Fyodorovich Orlov (Russian: Ю́рий Фёдорович Орло́в, born 13 '
            'August 1924 in Moscow) is Professor of Physics and Government at '
            'Cornell University, a former Soviet dissident, Soviet nuclear '
            'physicist and human rights activist, a founder of the Moscow '
            'Helsinki Group and Soviet Amnesty International group. He was '
            'declared a prisoner of conscience when served nine years in '
            'prison and internal exile for monitoring the Helsinki human '
            'rights accords as a founder of human rights movement in the '
            'Soviet Union.',
            'almaMater': 'http://dbpedia.org/resource/Institute_for_Theoretical_and_Experimental_Physics|http://dbpedia.org/resource/Moscow_State_University',
            'award': 'http://dbpedia.org/resource/Andrei_Sakharov_Prize_(APS)|http://dbpedia.org/resource/Carter-Menil_Human_Rights_Prize|http://dbpedia.org/resource/Honorary_degree',
            'birthDate': '1924-08-13',
            'birthPlace': 'http://dbpedia.org/resource/Moscow|http://dbpedia.org/resource/USSR',
            'categories': 'http://dbpedia.org/resource/Category:1924_births|http://dbpedia.org/resource/Category:20th-century_physicists|http://dbpedia.org/resource/Category:American_physicists|http://dbpedia.org/resource/Category:Amnesty_International_people|http://dbpedia.org/resource/Category:Amnesty_International_prisoners_of_conscience|http://dbpedia.org/resource/Category:Communist_Party_of_the_Soviet_Union_members|http://dbpedia.org/resource/Category:Cornell_University_faculty|http://dbpedia.org/resource/Category:Expelled_members_of_the_Communist_Party_of_the_Soviet_Union|http://dbpedia.org/resource/Category:Fellows_of_the_American_Academy_of_Arts_and_Sciences|http://dbpedia.org/resource/Category:Inmates_of_Lefortovo_Prison|http://dbpedia.org/resource/Category:Living_people|http://dbpedia.org/resource/Category:Moscow_Helsinki_Group|http://dbpedia.org/resource/Category:Moscow_State_University_alumni|http://dbpedia.org/resource/Category:People_forcibly_stripped_of_Soviet_citizenship|http://dbpedia.org/resource/Category:People_from_Moscow|http://dbpedia.org/resource/Category:Russian_memoirists|http://dbpedia.org/resource/Category:Russian_nuclear_physicists|http://dbpedia.org/resource/Category:Russian_physicists|http://dbpedia.org/resource/Category:Russian_political_writers|http://dbpedia.org/resource/Category:Soviet_dissidents|http://dbpedia.org/resource/Category:Soviet_emigrants_to_the_United_States|http://dbpedia.org/resource/Category:Soviet_expellees|http://dbpedia.org/resource/Category:Soviet_human_rights_activists|http://dbpedia.org/resource/Category:Soviet_nuclear_physicists|http://dbpedia.org/resource/Category:Soviet_people_of_World_War_II|http://dbpedia.org/resource/Category:Soviet_physicists|http://dbpedia.org/resource/Category:Soviet_prisoners_and_detainees',
            'child': 'Aleksandr|Dmitri|Lev',
            'citizenship': 'http://dbpedia.org/resource/Statelessness',
            'comment': 'Yuri Fyodorovich Orlov (Russian: Ю́рий Фёдорович Орло́в, born 13 '
            'August 1924 in Moscow) is Professor of Physics and Government at '
            'Cornell University, a former Soviet dissident, Soviet nuclear '
            'physicist and human rights activist, a founder of the Moscow '
            'Helsinki Group and Soviet Amnesty International group. He was '
            'declared a prisoner of conscience when served nine years in '
            'prison and internal exile for monitoring the Helsinki human '
            'rights accords as a founder of human rights movement in the '
            'Soviet Union.',
            'description': 'Russian physicist',
            'field': 'http://dbpedia.org/resource/Nuclear_physics',
            'fullName': 'Yuri Orlov',
            'gender': 'male',
            'givenName': 'Yuri',
            'isPrimaryTopicOf': 'http://en.wikipedia.org/wiki/Yuri_Orlov',
            'knownFor': 'http://dbpedia.org/resource/Human_rights_movement_in_the_Soviet_Union|http://dbpedia.org/resource/Soviet_atomic_bomb_project',
            'name': 'Yuri Fyodorovich Orlov|Yuri Orlov',
            'nationality': 'http://dbpedia.org/resource/Russians',
            'resource': 'http://dbpedia.org/resource/Yuri_Orlov',
            'source': 'http://dbpedia.org/data/Yuri_Orlov.json',
            'spouse': 'Irina Lagunova\n* Irina Valitova\n* Sidney Orlov',
            'surname': 'Orlov',
            'thumbnail': 'http://commons.wikimedia.org/wiki/Special:FilePath/Orlov_photo.jpg?width=300',
            'wasDerivedFrom': 'http://en.wikipedia.org/wiki/Yuri_Orlov?oldid=737603901',
            'wikiPageID': 848376,
            'wikiPageRevisionID': 737603901,
            'workplaces': 'Institute for Theoretical and Experimental Physics\n'
            '* Yerevan Physics Institute\n'
            '* Institute of Terrestrial Magnetism and Propagation of Radio '
            'Waves\n'
            '* Cornell University\n'
            '* American Academy of Arts and Sciences\n'
            '* subsidiary of Amnesty International in the Soviet Union\n'
            '* Moscow Helsinki Group'}

# %%
@pytest.fixture
def expected_al_biruni_data():
    return {'abstract': 'Abū Rayḥān Muḥammad ibn Aḥmad Al-Bīrūnī (Chorasmian/Persian: '
            'ابوریحان بیرونی\u200e\u200e Abū Rayḥān Bērōnī; New Persian: Abū '
            'Rayḥān Bīrūnī) (4/5 September 973 – 13 December 1048), known as '
            'Al-Biruni (Arabic: البيروني\u200e\u200e) in English, was a '
            'Khwarezmian Iranian Muslim scholar and polymath. Al-Biruni is '
            'regarded as one of the greatest scholars of the medieval Islamic '
            'era and was well versed in physics, mathematics, astronomy, and '
            'natural sciences, and also distinguished himself as a historian, '
            'chronologist and linguist. He was conversant in Khwarezmian, '
            'Persian, Arabic, Sanskrit, and also knew Greek, Hebrew and '
            'Syriac. He spent a large part of his life in Ghazni in '
            'modern-day Afghanistan, capital of the Ghaznavid dynasty which '
            'was based in what is now central-eastern Afghanistan. In 1017 he '
            'traveled to the Indian subcontinent and authored Tarikh Al-Hind '
            '(History of India) after exploring the Hindu faith practised in '
            'India. He was given the title "founder of Indology". He was an '
            'impartial writer on customs and creeds of various nations, and '
            'was given the title al-Ustadh ("The Master") for his remarkable '
            'description of early 11th-century India. He also made '
            'contributions to Earth sciences, and is regarded as the "father '
            'of geodesy" for his important contributions to that field, along '
            'with his significant contributions to geography.',
            'birthDate': '973-9-5',
            'birthPlace': 'Kath, Khwarezm, Samanid Empire',
            'categories': 'http://dbpedia.org/resource/Category:1048_deaths|http://dbpedia.org/resource/Category:10th-century_astrologers|http://dbpedia.org/resource/Category:10th-century_Iranian_people|http://dbpedia.org/resource/Category:10th-century_mathematicians|http://dbpedia.org/resource/Category:11th-century_astrologers|http://dbpedia.org/resource/Category:11th-century_astronomers|http://dbpedia.org/resource/Category:11th-century_geographers|http://dbpedia.org/resource/Category:11th-century_historians|http://dbpedia.org/resource/Category:11th-century_mathematicians|http://dbpedia.org/resource/Category:973_births|http://dbpedia.org/resource/Category:Al-Biruni|http://dbpedia.org/resource/Category:Alchemists_of_medieval_Islam|http://dbpedia.org/resource/Category:Anthropologists|http://dbpedia.org/resource/Category:Astrologers_of_medieval_Islam|http://dbpedia.org/resource/Category:Astronomers_of_medieval_Islam|http://dbpedia.org/resource/Category:Geographers_of_medieval_Islam|http://dbpedia.org/resource/Category:Ghaznavid_scholars|http://dbpedia.org/resource/Category:Historians_of_India|http://dbpedia.org/resource/Category:Indologists|http://dbpedia.org/resource/Category:Islamic_philosophers|http://dbpedia.org/resource/Category:Mathematicians_of_medieval_Islam|http://dbpedia.org/resource/Category:Medieval_Persian_astrologers|http://dbpedia.org/resource/Category:Medieval_Persian_astronomers|http://dbpedia.org/resource/Category:Medieval_Persian_geographers|http://dbpedia.org/resource/Category:Medieval_Persian_mathematicians|http://dbpedia.org/resource/Category:Persian_philosophers|http://dbpedia.org/resource/Category:Samanid_scholars|http://dbpedia.org/resource/Category:Scientists_who_worked_on_Qibla_determination',
            'comment': 'Abū Rayḥān Muḥammad ibn Aḥmad Al-Bīrūnī (Chorasmian/Persian: '
            'ابوریحان بیرونی\u200e\u200e Abū Rayḥān Bērōnī; New Persian: Abū '
            'Rayḥān Bīrūnī) (4/5 September 973 – 13 December 1048), known as '
            'Al-Biruni (Arabic: البيروني\u200e\u200e) in English, was a '
            'Khwarezmian Iranian Muslim scholar and polymath.',
            'deathDate': '1048-12-19',
            'deathPlace': 'http://dbpedia.org/resource/Ghazni',
            'description': 'Persian scholar and polymath',
            'fullName': 'Al-Biruni',
            'gender': 'male',
            'influenced': 'http://dbpedia.org/resource/Al-Khazini|http://dbpedia.org/resource/Al-Sijzi|http://dbpedia.org/resource/Avicenna|http://dbpedia.org/resource/Islamic_philosophy|http://dbpedia.org/resource/Islamic_science|http://dbpedia.org/resource/Maragha_observatory|http://dbpedia.org/resource/Omar_Khayyam|http://dbpedia.org/resource/Zakariya_al-Qazwini',
            'influencedBy': 'http://dbpedia.org/resource/Abu_Nasr_Mansur|http://dbpedia.org/resource/Al-Jahiz|http://dbpedia.org/resource/Al-Sijzi',
            'isPrimaryTopicOf': 'http://en.wikipedia.org/wiki/Al-Biruni',
            'name': 'Abū Rayḥān al-Bīrūnī',
            'resource': 'http://dbpedia.org/resource/Al-Biruni',
            'source': 'http://dbpedia.org/data/Al-Biruni.json',
            'thumbnail': 'http://commons.wikimedia.org/wiki/Special:FilePath/Biruni-russian.jpg?width=300',
            'wasDerivedFrom': 'http://en.wikipedia.org/wiki/Al-Biruni?oldid=745219133',
            'wikiPageID': 271975,
            'wikiPageRevisionID': 745219133
            }

# %%
@pytest.fixture
def expected_archimedes_data():
    return {'abstract': 'Archimedes of Syracuse (/ˌɑːkɪˈmiːdiːz/; Greek: Ἀρχιμήδης; '
            'c.\u2009287 BC – c.\u2009212 BC) was an Ancient Greek '
            'mathematician, physicist, engineer, inventor, and astronomer. '
            'Although few details of his life are known, he is regarded as '
            'one of the leading scientists in classical antiquity. Generally '
            'considered the greatest mathematician of antiquity and one of '
            'the greatest of all time, Archimedes anticipated modern calculus '
            'and analysis by applying concepts of infinitesimals and the '
            'method of exhaustion to derive and rigorously prove a range of '
            'geometrical theorems, including the area of a circle, the '
            'surface area and volume of a sphere, and the area under a '
            'parabola. Other mathematical achievements include deriving an '
            'accurate approximation of pi, defining and investigating the '
            'spiral bearing his name, and creating a system using '
            'exponentiation for expressing very large numbers. He was also '
            'one of the first to apply mathematics to physical phenomena, '
            'founding hydrostatics and statics, including an explanation of '
            'the principle of the lever. He is credited with designing '
            'innovative machines, such as his screw pump, compound pulleys, '
            'and defensive war machines to protect his native Syracuse from '
            'invasion. Archimedes died during the Siege of Syracuse when he '
            'was killed by a Roman soldier despite orders that he should not '
            'be harmed. Cicero describes visiting the tomb of Archimedes, '
            'which was surmounted by a sphere and a cylinder, which '
            'Archimedes had requested to be placed on his tomb, representing '
            'his mathematical discoveries. Unlike his inventions, the '
            'mathematical writings of Archimedes were little known in '
            'antiquity. Mathematicians from Alexandria read and quoted him, '
            'but the first comprehensive compilation was not made until c. '
            '530 AD by Isidore of Miletus in Byzantine Constantinople, while '
            'commentaries on the works of Archimedes written by Eutocius in '
            'the sixth century AD opened them to wider readership for the '
            "first time. The relatively few copies of Archimedes' written "
            'work that survived through the Middle Ages were an influential '
            'source of ideas for scientists during the Renaissance, while the '
            'discovery in 1906 of previously unknown works by Archimedes in '
            'the Archimedes Palimpsest has provided new insights into how he '
            'obtained mathematical results.',
            'birthDate': '-287-0-0',
            'birthPlace': 'http://dbpedia.org/resource/Magna_Graecia|http://dbpedia.org/resource/Syracuse,_Sicily',
            'categories': 'http://dbpedia.org/resource/Category:210s_BC_deaths|http://dbpedia.org/resource/Category:280s_BC_births|http://dbpedia.org/resource/Category:3rd-century_BC_Greek_people|http://dbpedia.org/resource/Category:3rd-century_BC_writers|http://dbpedia.org/resource/Category:Ancient_Greek_engineers|http://dbpedia.org/resource/Category:Ancient_Greek_inventors|http://dbpedia.org/resource/Category:Ancient_Greek_mathematicians|http://dbpedia.org/resource/Category:Ancient_Greek_physicists|http://dbpedia.org/resource/Category:Ancient_Greeks_who_were_murdered|http://dbpedia.org/resource/Category:Ancient_Syracusians|http://dbpedia.org/resource/Category:Archimedes|http://dbpedia.org/resource/Category:Buoyancy|http://dbpedia.org/resource/Category:Doric_Greek_writers|http://dbpedia.org/resource/Category:Fluid_dynamicists|http://dbpedia.org/resource/Category:Geometers|http://dbpedia.org/resource/Category:Hellenistic-era_philosophers|http://dbpedia.org/resource/Category:Murdered_scientists|http://dbpedia.org/resource/Category:People_from_Syracuse,_Sicily|http://dbpedia.org/resource/Category:Sicilian_Greeks|http://dbpedia.org/resource/Category:Sicilian_mathematicians|http://dbpedia.org/resource/Category:Sicilian_scientists',
            'comment': 'Archimedes of Syracuse (/ˌɑːkɪˈmiːdiːz/; Greek: Ἀρχιμήδης; '
            'c.\u2009287 BC – c.\u2009212 BC) was an Ancient Greek '
            'mathematician, physicist, engineer, inventor, and astronomer. '
            'Although few details of his life are known, he is regarded as one '
            'of the leading scientists in classical antiquity. Generally '
            'considered the greatest mathematician of antiquity and one of the '
            'greatest of all time, Archimedes anticipated modern calculus and '
            'analysis by applying concepts of infinitesimals and the method of '
            'exhaustion to derive and rigorously prove a range of geometrical '
            'theorems, including the area of a circle, the surface area and '
            'volume of a sphere, and the area under a parabola.',
            'deathDate': '-212-1-1',
            'deathPlace': 'http://dbpedia.org/resource/Magna_Graecia|http://dbpedia.org/resource/Syracuse,_Sicily',
            'description': 'Greek mathematician, physicist, engineer, inventor, and '
            'astronomer',
            'field': 'http://dbpedia.org/resource/Astronomy|http://dbpedia.org/resource/Engineering|http://dbpedia.org/resource/Invention|http://dbpedia.org/resource/Mathematics|http://dbpedia.org/resource/Physics',
            'fullName': 'Archimedes',
            'gender': 'male',
            'influenced': 'http://dbpedia.org/resource/Gerolamo_Cardano|http://dbpedia.org/resource/René_Descartes',
            'isPrimaryTopicOf': 'http://en.wikipedia.org/wiki/Archimedes',
            'knownFor': "http://dbpedia.org/resource/Archimedes'_principle|http://dbpedia.org/resource/Archimedes'_screw|http://dbpedia.org/resource/Archimedes'_use_of_infinitesimals|http://dbpedia.org/resource/Fluid_statics|http://dbpedia.org/resource/Lever|http://dbpedia.org/resource/Neusis_construction",
            'name': 'Archimedes|Archimedes of Syracuse',
            'resource': 'http://dbpedia.org/resource/Archimedes',
            'source': 'http://dbpedia.org/data/Archimedes.json',
            'thumbnail': 'http://commons.wikimedia.org/wiki/Special:FilePath/Domenico-Fetti_Archimedes_1620.jpg?width=300',
            'wasDerivedFrom': 'http://en.wikipedia.org/wiki/Archimedes?oldid=744804092',
            'wikiPageID': 1844,
            'wikiPageRevisionID': 744804092
            }

# %%
@pytest.fixture
def expected_stephen_paul_data():
    return {'abstract': 'Stephen F. Paul (November 13, 1953 – September 15, 2012) was a '
            'physicist at the Princeton Plasma Physics Laboratory at '
            'Princeton University. He created and patented the P-series '
            'fuels, a new, liquid, renewable, non-petroleum gasoline '
            'formulation. He was in the process of converting an unused '
            'sludge plant in Trenton, NJ to process organic waste for fuel '
            'before he died. He lived in New Jersey with his wife. He had '
            'three grown children. He had a BS from Cornell University and '
            "received his master's degree and PhD from Columbia University.",
            'almaMater': 'http://dbpedia.org/resource/Columbia_University|http://dbpedia.org/resource/Cornell_University',
            'birthDate': '1953-11-13',
            'categories': 'http://dbpedia.org/resource/Category:1953_births|http://dbpedia.org/resource/Category:2012_deaths|http://dbpedia.org/resource/Category:American_physicists|http://dbpedia.org/resource/Category:Cornell_University_alumni',
            'citizenship': 'http://dbpedia.org/resource/United_States',
            'comment': 'Stephen F. Paul (November 13, 1953 – September 15, 2012) was a '
            'physicist at the Princeton Plasma Physics Laboratory at Princeton '
            'University. He created and patented the P-series fuels, a new, '
            'liquid, renewable, non-petroleum gasoline formulation. He was in '
            'the process of converting an unused sludge plant in Trenton, NJ '
            'to process organic waste for fuel before he died. He lived in New '
            'Jersey with his wife. He had three grown children. He had a BS '
            "from Cornell University and received his master's degree and PhD "
            'from Columbia University.',
            'deathDate': '2012-09-15',
            'description': 'American physicist',
            'doctoralAdvisor': 'Prof. Bob Gross',
            'field': 'http://dbpedia.org/resource/Chemistry|http://dbpedia.org/resource/Physics',
            'fullName': 'Stephen Paul (physicist)',
            'gender': 'male',
            'givenName': 'Stephen',
            'isPrimaryTopicOf': 'http://en.wikipedia.org/wiki/Stephen_Paul_(physicist)',
            'knownFor': 'http://dbpedia.org/resource/Organic_waste|http://dbpedia.org/resource/P-series_fuels|http://dbpedia.org/resource/Sludge',
            'name': 'Stephen F. Paul|Stephen Paul',
            'resource': 'http://dbpedia.org/resource/Stephen_Paul_(physicist)',
            'source': 'http://dbpedia.org/data/Stephen_Paul_(physicist).json',
            'surname': 'Paul',
            'wasDerivedFrom': 'http://en.wikipedia.org/wiki/Stephen_Paul_(physicist)?oldid=740746972',
            'wikiPageID': 20077885,
            'wikiPageRevisionID': 740746972,
            'workplaces': 'http://dbpedia.org/resource/Princeton_Plasma_Physics_Laboratory|http://dbpedia.org/resource/Princeton_University'
           }

# %%
# %%run_pytest[clean] -v --color=yes
#
# def test_create_physicist_data_einstein(expected_albert_einstein_data):
#     assert(create_physicist_data(json_lines[22]) ==
#            expected_albert_einstein_data)
#
# def test_create_physicist_data_marie_curie(expected_marie_curie_data):
#     assert(create_physicist_data(json_lines[672]) ==
#            expected_marie_curie_data)
#
# def test_create_physicist_data_max_born(expected_max_born_data):
#     assert(create_physicist_data(json_lines[693]) ==
#            expected_max_born_data)
#
# def test_create_physicist_data_niels_bohr(expected_niels_bohr_data):
#     assert(create_physicist_data(json_lines[741]) ==
#            expected_niels_bohr_data)
#
# def test_create_physicist_data_homi_bhabha(expected_homi_bhabha_data):
#     assert(create_physicist_data(json_lines[429]) ==
#            expected_homi_bhabha_data)
#
# def test_create_physicist_data_yuri_orlov(expected_yuri_orlov_data):
#     assert(create_physicist_data(json_lines[1054]) ==
#            expected_yuri_orlov_data)
#
# def test_create_physicist_data_al_biruni(expected_al_biruni_data):
#     assert(create_physicist_data(json_lines[24]) ==
#            expected_al_biruni_data)
#
# def test_create_physicist_data_archimedes(expected_archimedes_data):
#     assert(create_physicist_data(json_lines[78]) ==
#            expected_archimedes_data)
#
# def test_create_physicist_data_stephen_paul(expected_stephen_paul_data):
#     assert(create_physicist_data(json_lines[933]) ==
#            expected_stephen_paul_data)
#
# def test_create_physicist_data_david_carroll(expected_david_carroll_data):
#     assert(create_physicist_data(json_lines[204]) ==
#            expected_david_carroll_data)
