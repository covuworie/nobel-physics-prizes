# %%
import ipytest
import pytest

# %%
PYTEST_OPTIONS = ['-v', '--color=yes']

# %%
@pytest.fixture
def notable_physicists():
    return [
         'A. P. Balachandran',
         'Aage Bohr',
         'Aaldert Wapstra',
         'Abdul Qadeer Khan',
         'Abdus Salam',
         'Abraham Alikhanov',
         'Abraham Bennet',
         'Abraham H. Taub',
         'Abraham Pais',
         'Abram Ioffe',
         'Abū Rayhān al-Bīrūnī',
         'Adam Riess',
         'Adolf Kratzer',
         'Adolfas Jucys',
         'Adriaan Fokker',
         'Adrian Melott',
         'Aiyalam Parameswaran Balachandran',
         'Akira Tonomura',
         'Al Beruni',
         'Al Farabi',
         'Alain Aspect',
         'Alain Haché',
         'Alan Andrew Watson',
         'Alan Guth',
         'Alan Schoen',
         'Alan Walsh (physicist)',
         'Albert Abraham Michelson',
         'Albert Einstein',
         'Albert Fert',
         'Alejandro Corichi',
         'Aleksandr Mikhailovich Lyapunov',
         'Aleksandr Stoletov',
         'Alessandro Volta',
         'Alexander Animalu',
         'Alexander Friedman',
         'Alexander Graham Bell',
         'Alexander M. Polyakov',
         'Alexander Prokhorov',
         'Alexander R. Hamilton',
         'Alexander Zamolodchikov',
         'Alexei Alexeyevich Abrikosov',
         'Alexei Kitaev',
         'Alexei Smirnov (physicist)',
         'Alexei Yuryevich Smirnov',
         'Alexei Zamolodchikov',
         'Alfred Kastler',
         'Alfred Lee Loomis',
         'Alfred-Marie Liénard',
         'Alhazen',
         'Ali Chamseddine',
         'Ali Javan',
         'Ali Moustafa Mosharafa',
         'Alladi Ramakrishnan',
         'Allan McLeod Cormack',
         'Alvin Weinberg',
         'Amal Kumar Raychaudhuri',
         'Amanda Barnard',
         'Amédée Mouchez',
         'Amedeo Avogadro',
         'Amos Dolbear',
         'Amrom Harry Katz',
         'Anatoly Vlasov',
         'Anders Jonas Ångström',
         'Andre Geim',
         'Andrea M. Ghez',
         'Andreas Jaszlinszky',
         'Andrei Sakharov',
         'André-Marie Ampère',
         'Andrew D. Huxley',
         'Andrew Strominger',
         'Anja Cetti Andersen',
         'Ann Nelson',
         'Antal Jákli',
         'Anthony Ichiro Sanda',
         'Anthony James Leggett',
         'Anthony M. Johnson',
         'Anthony Zee',
         'Anton Zeilinger',
         'Antonino Zichichi',
         'Antony Garrett Lisi',
         'Antony Hewish',
         'Archibald Howie',
         'Archibald Low',
         'Archimedes',
         'Ari Brynjolfsson',
         'Aristarchus of Samos',
         'Aristotle',
         'Arno Allan Penzias',
         'Arnold Sommerfeld',
         'Arpad Elo',
         'Arsenij Sokolov',
         'Artem Alikhanian',
         'Arthur B. McDonald',
         'Arthur Compton',
         'Arthur Eddington',
         'Arthur Holly Compton',
         'Arthur Iberall',
         'Arthur Korn',
         'Arthur Leonard Schawlow',
         'Arthur Maitland',
         'Arthur Milne',
         'Arthur Stanley Eddington',
         'Arthur Wightman',
         'Aryabhata',
         'Ashok Das',
         'Ashoke Sen',
         'Ashutosh Kotwal',
         'Asım Orhan Barut',
         'Asoke Nath Mitra',
         'Ataç İmamoğlu',
         'August Krönig',
         'Augustin-Jean Fresnel',
         'Avicenna',
         'Ayşe Erzan',
         'Ayyub Guliyev',
         'B. Roy Frieden',
         'Baien Tomlin',
         'Balthasar van der Pol',
         'Barton Zwiebach',
         'Basilis C. Xanthopoulos',
         'Behram Kursunoglu',
         'Behram Kurşunoğlu',
         'Ben Roy Mottelson',
         'Benjamin Franklin',
         'Benjamin Lee (physicist)',
         'Benoît Paul Émile Clapeyron',
         'Bent Sørensen (physicist)',
         'Bernard de Wit',
         'Bernhard Philberth',
         'Bertha Swirles',
         'Bertram Brockhouse',
         'Bice Sechi-Zorn',
         'Bimla Buti',
         'Blaise Pascal',
         'Boris Chirikov',
         'Boris Jacobi',
         'Boris Podolsky',
         'Boyd Bartlett',
         'Brandon Carter',
         'Brendan Scaife',
         'Brian Cox (physicist)',
         'Brian David Josephson',
         'Brian Greene',
         'Brian May',
         'Brian Schmidt',
         'Bruno Pontecorvo',
         'Bruno Rossi',
         'Bruno Touschek',
         'Bruno Zumino',
         'Burchard de Volder',
         'Burton Richter',
         'C. R. Hagen',
         'C.H.D. Buys Ballot',
         'Carl August Steinheil',
         'Carl David Anderson',
         'Carl Eckart',
         'Carl Friedrich Gauss',
         'Carl Friedrich von Weizsäcker',
         'Carl Hermann',
         'Carl M. Bender',
         'Carl Ramsauer',
         'Carl Richard Hagen',
         'Carl Sagan',
         'Carl Wieman',
         'Carl-Gustav Arvid Rossby',
         'Carlo Beenakker',
         'Carlo Marangoni',
         'Carlo Rovelli',
         'Carlo Rubbia',
         'Carlos E.M. Wagner',
         'Carolina Henriette Mac Gillavry',
         'Cecil Frank Powell',
         'Cesar Lattes',
         'Chandrasekhara Venkata Raman',
         'Charles Critchfield',
         'Charles Edouard Guillaume',
         'Charles Galton Darwin',
         'Charles Glover Barkla',
         'Charles H. Henry',
         'Charles K. Kao',
         'Charles Thomson Rees Wilson',
         'Charles Thorn',
         'Charles Townes',
         'Charles-Augustin de Coulomb',
         'Charlotte Riefenstahl',
         'Chen Ning Yang',
         'Chennupati Jagadish',
         'Chien-Shiung Wu',
         'Chris Lintott',
         'Christiaan Huygens',
         'Christian Doppler',
         'Christian Gerthsen',
         'Christof Wetterich',
         'Christopher T. Hill',
         'Claude Cohen-Tannoudji',
         'Clemens C. J. Roothaan',
         'Clifford Shull',
         'Clinton Davisson',
         'Colin Webb',
         'Cosmas Zachos',
         'Craige Schensted',
         'Cumrun Vafa',
         'Curtis Callan',
         'Dam Thanh Son',
         'Daniel Bernoulli',
         'Daniel C. Tsui',
         'Daniel Friedan',
         'Daniel Greenberger',
         'Daniel Z. Freedman',
         'David Awschalom',
         'David Bohm',
         'David Brewster',
         'David Carroll (physicist)',
         'David Deutsch',
         'David Enskog',
         'David Finkelstein',
         'David Gross',
         'David J. Griffiths',
         'David J. Wineland',
         'David Lee (physicist)',
         'David Lindley (physicist)',
         'David M. Dennison',
         'David Merritt',
         'David Olive',
         'David Ruelle',
         'David Z Albert',
         'Daya Shankar Kulshreshtha',
         'Deborah S. Jin',
         'Democritus',
         'Denis Evans',
         'Denis Weaire',
         'Dennis Gabor',
         'Dennis Sciama',
         'Dennis William Sciama',
         'Derek Abbott',
         'Dimitri Nanopoulos',
         'Dmitry Shirkov',
         'Dmitry Zubarev',
         'Donald A. Glaser',
         'Dorothy Crowfoot Hodgkin',
         'Douglas D. Osheroff',
         'Douglas Hartree',
         'Durmus A. Demir',
         'Edward Bouchet',
         'Edward Condon',
         'Edward Mills Purcell',
         'Edward P. Ney',
         'Edward Ramberg',
         'Edward Teller',
         'Edward Victor Appleton',
         'Edward Witten',
         'Edwin C. Kemble',
         'Edwin Ernest Salpeter',
         'Edwin Hall',
         'Edwin Powell Hubble',
         'Edwin Thompson Jaynes',
         'Egon Orowan',
         'Elephter Andronikashvili',
         'Elmer Imes',
         'Emil Wiechert',
         'Emil Wolf',
         'Émile Verdet',
         'Emilio G. Segre',
         'Emmy Noether',
         'Enrico Fermi',
         'Erdal İnönü',
         'Erhard Kietz',
         'Eric Allin Cornell',
         'Eric Poisson',
         'Erik Verlinde',
         'Ernest Courant',
         'Ernest Esclangon',
         'Ernest Lawrence',
         'Ernest Rutherford',
         'Ernest Walton',
         'Ernest William Titterton',
         'Ernst Brüche',
         'Ernst Chladni',
         'Ernst equation',
         'Ernst Ising',
         'Ernst Karl Abbe',
         'Ernst Mach',
         'Ernst Ruska',
         'Ernst Stueckelberg',
         'Erwin Fues',
         'Erwin Schrödinger',
         'Étienne-Gaspard Robert',
         'Étienne-Louis Malus',
         'Ettore Majorana',
         'Eugene Feenberg',
         'Eugene T. Booth',
         'Eugene Wigner',
         'Eva Silverstein',
         'Evangelista Torricelli',
         'Evans Hayward',
         'Evgeny Lifshitz',
         'Evgeny Velikhov',
         'Ewald Wollny',
         'Ezra Getzler',
         'Ezra T. Newman',
         'F. J. Duarte',
         'Felix Bloch',
         'Felix Ehrenhaft',
         'Félix Savart',
         'Félix Ynduráin',
         'Feza Gürsey',
         'Floyd K. Richtmyer',
         'Francis G. Slack',
         'Francisco Jose Yndurain',
         'Francisco Jose Yndurain Muñoz',
         'François Englert',
         'François Jean Dominique Arago',
         'Frank J. Tipler',
         'Frank Wilczek',
         'Franz Aepinus',
         'Franz S. Exner',
         'Fred Alan Wolf',
         'Fred Hoyle',
         'Frederick Grover',
         'Frederick Reines',
         'Frederick Seitz',
         'Freeman Dyson',
         'Friedrich Burmeister',
         'Friedrich Ernst Dorn',
         'Friedrich Hasenöhrl',
         'Friedrich Hund',
         'Friedwardt Winterberg',
         'Fritjof Capra',
         'Frits Zernike',
         'Fritz Houtermans',
         'Fulvio Melia',
         'G. N. Glasoe',
         'G. V. Skrotskii',
         'Gabriel Fahrenheit',
         'Gabriel Jonas Lippmann',
         'Gabriele Rabel',
         'Gabriele Veneziano',
         'Galileo Galilei',
         'Gaspard-Gustave Coriolis',
         'Geoffrey Chew',
         'Geoffrey Ingram Taylor',
         'Georg Ohm',
         'George B. Pegram',
         'George E. Smith',
         'George Eugene Uhlenbeck',
         'George Francis FitzGerald',
         'George Gabriel Stokes',
         'George Gamow',
         'George Green (mathematician)',
         'George Paget Thomson',
         'George Smoot',
         'George Sterman',
         'George Sudarshan',
         'George W. Clark',
         'George William Hill',
         'George Zweig',
         'Georges Charpak',
         'Georges Lemaître',
         'Georges Sagnac',
         'Georges-Louis Le Sage',
         'Georgy Flyorov',
         'Gerald B. Cleaver',
         'Gerald Feinberg',
         'Gerald Goertzel',
         'Gerald Guralnik',
         "Gerard K. O'Neill",
         "Gerardus 't Hooft",
         'Gerd Binnig',
         'Gersh Budker',
         'Gian F. Giudice',
         'Gian-Carlo Wick',
         'Gilbert Ronald Bainbridge',
         'Giorgio Parisi',
         'Giovanni Battista Venturi',
         'Giovanni Ciccotti',
         'Gleb Wataghin',
         'Goran Senjanovic',
         'Gottfried Leibniz',
         'Gottfried Wilhelm Leibniz',
         'Gregor Wentzel',
         'Gregory Jaczko',
         'Grigory Landsberg',
         'Guglielmo Marconi',
         'Guido Altarelli',
         'Gunnar Nordström',
         'Gurgen Askaryan',
         'Gustaf Dalén',
         'Gustav Kirchhoff',
         'Gustav Ludwig Hertz',
         'Gustave-Adolphe Hirn',
         'H. Dieter Zeh',
         'H. Pierre Noyes',
         'Hagen Kleinert',
         'Haim Harari',
         'Hannes Olof Gösta Alfvén',
         'Hans Bethe',
         'Hans Buchdahl',
         'Hans Christian Ørsted',
         'Hans Geiger',
         'Hans Georg Dehmelt',
         'Hans Henrik Andersen',
         'Hans Ziegler (physicist)',
         'Harald Fuchs',
         'Harald J.W. Mueller-Kirsten',
         'Harold E. Puthoff',
         'Harrie Massey',
         'Hasan Abdullayev',
         'Heike Kamerlingh Onnes',
         'Heinrich Kayser',
         'Heinrich Rohrer',
         'Heinrich Rudolf Hertz',
         'Heinrich Welker',
         'Heinz Barwich',
         'Heinz Pagels',
         'Heinz Pose',
         'Helen Quinn',
         'Helmut Hönl',
         'Hendrik Casimir',
         'Hendrik Kramers',
         'Hendrik Lorentz',
         'Henk Dorgelo',
         'Henri Becquerel',
         'Henri Poincaré',
         'Henry Cavendish',
         'Henry Margenau',
         'Henry Moseley',
         'Henry Stapp',
         'Henry Way Kendall',
         'Heraclides Ponticus',
         'Herbert Kroemer',
         'Herbert L. Anderson',
         'Herman Feshbach',
         'Hermann Brück',
         'Hermann von Helmholtz',
         'Hermann Weyl',
         'Hideki Yukawa',
         'Hideo Ohno',
         'Hippolyte Fizeau',
         'Hiranmay Sen Gupta',
         'Holger Bech Nielsen',
         'Homi J. Bhabha',
         'Horst Ludwig Störmer',
         'Howard Brandt',
         'Howard Georgi',
         'Hubert Reeves',
         'Hugh David Politzer',
         'Ibn al-Haytham',
         'Igor Klebanov',
         'Igor Tamm',
         'Igor Ternov',
         'Igor Vasilyevich Kurchatov',
         'Igor Yevgenyevich Tamm',
         'Ilya Frank',
         'Ilya Prigogine',
         'Irène Joliot-Curie',
         'Irving Langmuir',
         'Isaac Beeckman',
         'Isaac Newton',
         'Isaak Markovich Khalatnikov',
         'Isidor Isaac Rabi',
         'Isidor Sauers',
         'İsmail Hakkı Duru',
         'Ivan Pulyuy',
         'Ivar Giaever',
         'J. Hans D. Jensen',
         'J. J. Thomson',
         'Jack Kilby',
         'Jack Steinberger',
         'Jacques Villain',
         'Jagadeesh Moodera',
         'Jagadish Chandra Bose',
         'Jainendra Jain',
         'Jamal Nazrul Islam',
         'James Alfred Ewing',
         'James Binney',
         'James Bjorken',
         'James Chadwick',
         'James Clerk Maxwell',
         'James Cronin',
         'James David Forbes',
         'James Dewar',
         'James E. Faller',
         'James Franck',
         'James Glimm',
         'James Hopwood Jeans',
         'James Prescott Joule',
         'James Rainwater',
         'James W. LaBelle',
         'James Wait',
         'James Watt',
         'Jan Zaanen',
         'Jayant Narlikar',
         'Jean Baptiste Perrin',
         'Jean Charles Athanase Peltier',
         'Jean Dalibard',
         'Jean Henri van Swinden',
         "Jean le Rond d'Alembert",
         'Jean Zinn-Justin',
         'Jean-Baptiste Biot',
         'Jean-Philippe Bouchaud',
         'Jean-Pierre Vigier',
         'Jeff Forshaw',
         'Jeffrey Goldstone',
         'Jens Martin Knudsen',
         'Jerome Isaac Friedman',
         'Jim Al-Khalili',
         'Joan Maie Freeman',
         'João Magueijo',
         'Jocelyn Bell Burnell',
         'Joël Scherk',
         'Jogesh Pati',
         'Johann Baptiste Horvath',
         'Johann Georg Tralles',
         'Johann Gottlieb Nörremberg',
         'Johann Jakob Balmer',
         'Johann Josef Loschmidt',
         'Johannes Bosscha',
         'Johannes Diderik van der Waals',
         'Johannes Fischer',
         'Johannes Georg Bednorz',
         'Johannes Kepler',
         'Johannes Martinus Burgers',
         'Johannes Rydberg',
         'Johannes Stark',
         'John Alexander Simpson',
         'John Archibald Wheeler',
         'John Bardeen',
         'John C. Mather',
         'John C. Slater',
         'John Cardy',
         'John Clive Ward',
         'John Cockcroft',
         'John Dalton',
         'John Ellis (physicist)',
         'John G. Cramer',
         'John Gribbin',
         'John H. Hubbell',
         'John Hartnett (physicist)',
         'John Hasbrouck van Vleck',
         'John Henry Poynting',
         'John Henry Schwarz',
         'John Herapath',
         'John Hopkinson',
         'John Hubbard (physicist)',
         'John Iliopoulos',
         'John J. Montgomery',
         'John J. Turin',
         'John James Waterston',
         'John Kerr (physicist)',
         'John L. Hall',
         'John Lennard-Jones',
         'John Leslie (physicist)',
         'John Linsley',
         'John Nye (scientist)',
         'John Pasta',
         'John Polkinghorne',
         'John R. Winckler',
         'John Robert Schrieffer',
         'John Sealy Townsend',
         'John Stewart Bell',
         'John Tyndall',
         'John von Neumann',
         'John Zeleny',
         'Jonathan Dowling',
         'José Enrique Moyal',
         'José W. F. Valle',
         'Joseph Fourier',
         'Joseph H. Eberly',
         'Joseph Henry',
         'Joseph Hooton Taylor, Jr.',
         'Joseph Larmor',
         'Joseph Louis Gay-Lussac',
         'Joseph Louis Lagrange',
         'Joseph Lykken',
         'Joseph Plateau',
         'Joseph Polchinski',
         'Joseph Romm',
         'Joseph Rotblat',
         'Joseph Stefan',
         'Joseph Swan',
         'Joseph von Fraunhofer',
         'Josiah Willard Gibbs',
         'Juan Maldacena',
         'Juan Martín Maldacena',
         'Juansher Chkareuli',
         'Jules Aarons',
         'Julia Yeomans',
         'Julian Schwinger',
         'Julius Wess',
         'Jürg Fröhlich',
         'Juris Upatnieks',
         'K. S. Babu',
         'Kai Siegbahn',
         'Kan-Chang Wang',
         'Karl Alexander Müller',
         'Karl Bechert',
         'Karl Compton',
         'Karl Ferdinand Braun',
         'Karl Glitscher',
         'Karl Herzfeld',
         'Karl L. Littrow',
         'Karl Schwarzschild',
         'Karl Wirtz',
         'Karl Zimmer',
         'Karl-Heinrich Riewe',
         'Kathryn Moler',
         'Kazimierz Fajans',
         'Kees A. Schouhamer Immink',
         'Kendal Nezan',
         'Kenneth G. Wilson',
         'Kenneth Lane (physicist)',
         'Kenneth Young (physicist)',
         'Kip Stephen Thorne',
         'Kip Thorne',
         'Klaus von Klitzing',
         'Konstantin Novoselov',
         'Konstantin Petrzhak',
         'Kurt Binder',
         'Kyriakos Tamvakis',
         'Lars Onsager',
         'Laura Maria Caterina Bassi',
         'Laura Mersini-Houghton',
         'Lawrence Krauss',
         'Lawrence M. Krauss',
         'Lee Smolin',
         'Lene Vestergaard Hau',
         'Leo Esaki',
         'Leo Graetz',
         'Leo Kadanoff',
         'Leo Szilard',
         'Leó Szilárd',
         'Léon Brillouin',
         'Leon Cooper',
         'Léon Foucault',
         'Leon M. Lederman',
         'Léon Van Hove',
         'Leonard Salomon Ornstein',
         'Leonard Susskind',
         'Leonhard Euler',
         'Leonid Isaakovich Mandelshtam',
         'Leopoldo Nobili',
         'Lev Artsimovich',
         'Lev Davidovich Landau',
         "Lev Gor'kov",
         'Lev Landau',
         'Lev Okun',
         'Lev Shubnikov',
         'Lew Kowarski',
         'Lewi Tonks',
         'Lincoln Wolfenstein',
         'Lisa Randall',
         'Lise Meitner',
         'Loránd Eötvös',
         'Lord Rayleigh',
         'Lorella Jones',
         'Lothar Nordheim',
         'Louis Essen',
         'Louis Néel',
         'Louis Rendu',
         'Louis Slotin',
         'Louis, 7th duc de Broglie',
         'Louis-Victor de Broglie',
         'Lowell S. Brown',
         'Luboš Motl',
         'Luciano Maiani',
         'Lucretius',
         'Ludvig Faddeev',
         'Ludvig Lorenz',
         'Ludwig Boltzmann',
         'Ludwig Prandtl',
         'Ludwig Waldmann',
         'Ludwig Zehnder',
         'Ludwik Silberstein',
         'Luigi Galvani',
         'Luigi Puccianti',
         'Luis Walter Alvarez',
         'Macedonio Melloni',
         'Mahmoud Hessaby',
         'Makoto Kobayashi (physicist)',
         'Mambillikalathil Govind Kumar Menon',
         'Manfred Eigen',
         'Manfred von Ardenne',
         'Mani Lal Bhaumik',
         'Manne Siegbahn',
         'Marcel Brillouin',
         'Marcela Carena',
         'Marcia Barbosa',
         'Margrete Heiberg Bose',
         'Maria Goeppert Mayer',
         'Maria Goeppert-Mayer',
         'Maria Spiropulu',
         'Marian Smoluchowski',
         'Marie Alfred Cornu',
         'Marie Curie',
         'Mark B. Wise',
         'Mark G. Raizen',
         'Mark Oliphant',
         'Marshall Rosenbluth',
         'Martin Bojowald',
         'Martin Gutzwiller',
         'Martin Knudsen',
         'Martin Lewis Perl',
         'Martin Rees, Baron Rees of Ludlow',
         'Martin Ryle',
         'Martin Schadt',
         'Martin Tajmar',
         'Martinus J. G. Veltman',
         'Martinus J.G. Veltman',
         'Marvin D. Girardeau',
         'Marvin Leonard Goldberger',
         'Mary K. Gaillard',
         'Masatoshi Koshiba',
         'Matthew Koss',
         'Matthew Sanders',
         'Maurice Goldhaber',
         'Maurice Loewy',
         'Max Born',
         'Max Delbrück',
         'Max Planck',
         'Max Steenbeck',
         'Max Tegmark',
         'Max Volmer',
         'Max von Laue',
         'Maxim Chernodub',
         'Megh Nad Saha',
         'Mehran Kardar',
         'Melvin Lax',
         'Melvin Schwartz',
         'Menas Kafatos',
         'Mendel Sachs',
         'Michael Faraday',
         'Michael Green (physicist)',
         'Michael R. Douglas',
         'Michael Woolfson',
         'Michio Kaku',
         'Miguel Alcubierre',
         'Miguel Ángel Virasoro (physicist)',
         'Mihajlo Idvorski Pupin',
         'Mikhail Lavrentyev',
         'Mikhail Lomonosov',
         'Mikhail Shifman',
         'Mikhail Vasilievich Ostrogradsky',
         'Milla Baldo-Ceolin',
         'Milton S. Plesset',
         'Mitchell Feigenbaum',
         'Moses H. W. Chan',
         'Moustafa Mosharafa',
         'Murray Gell-Mann',
         'Naomi Ginsberg',
         'Nasir al-Din Tusi',
         'Nathan Isgur',
         'Nathan Rosen',
         'Nathan Seiberg',
         'Neil Ashby',
         'Neil deGrasse Tyson',
         'Neil Turok',
         'Nevill Mott',
         'Nicola Cabibbo',
         'Nicola Spaldin',
         'Nicolaas Bloembergen',
         'Nicolás Cabrera',
         'Nicolas Léonard Sadi Carnot',
         'Nicolaus Copernicus',
         'Nicole Oresme',
         'Niels Bohr',
         'Nihat Berker',
         'Nikola Tesla',
         'Nikolaus Riehl',
         'Nikolay Basov',
         'Nikolay Bogolyubov',
         'Nikolay Semyonov',
         'Nikolay Sergeevich Krylov',
         'Nikolay Umov',
         'Nima Arkani-Hamed',
         'Nina Marković',
         'Norman Foster Ramsey, Jr.',
         'Oleg Losev',
         'Oleg Sushkov',
         'Oliver Heaviside',
         'Oliver Lodge',
         'Omar Khayyám',
         'Osborne Reynolds',
         'Oscar Sala',
         'Oskar Klein',
         'Otto Frisch',
         'Otto Hahn',
         'Otto Scherzer',
         'Otto Stern',
         'Owen Chamberlain',
         'Owen Willans Richardson',
         'Pamela L. Gay',
         'Pascual Jordan',
         'Patrick Blackett',
         'Paul Davies',
         'Paul Dirac',
         'Paul Drude',
         'Paul Ehrenfest',
         'Paul Frampton',
         'Paul G. Hewitt',
         'Paul Harteck',
         'Paul J. Steinhardt',
         'Paul John Ellis',
         'Paul Langevin',
         'Paul Peter Ewald',
         'Paul Werbos',
         'Pavel Alekseyevich Cherenkov',
         'Payam Taiebyzadeh',
         'Percy Williams Bridgman',
         'Per-Olov Löwdin',
         'Pervez Hoodbhoy',
         'Peter Adolf Thiessen',
         'Peter Andreas Hansen',
         'Peter Debye',
         'Peter Freund',
         'Peter Goddard (physicist)',
         'Peter Grünberg',
         'Peter Higgs',
         'Peter Mansfield',
         'Peter van Nieuwenhuizen',
         'Peter Westervelt',
         'Peter Zoller',
         'Petr Paucek',
         'Philip Warren Anderson',
         'Philipp Lenard',
         'Phyllis S. Freier',
         'Physicist',
         'Piara Singh Gill',
         'Pierre Curie',
         'Pierre Louis Dulong',
         'Pierre Ramond',
         'Pierre-Gilles de Gennes',
         'Pierre-Simon Laplace',
         'Pieter van Musschenbroek',
         'Pieter Zeeman',
         'Polykarp Kusch',
         'Pran Nath',
         'Predhiman Krishan Kaw',
         'Predrag Cvitanović',
         'Pyotr Kapitsa',
         'Pyotr Nikolaevich Lebedev',
         'Pythagoras',
         'Rafael Sorkin',
         'Ralph Asher Alpher',
         'Ralph H. Fowler',
         'Ralph Kronig',
         'Raman Sundrum',
         'Ramón E. López',
         'Ranjan Roy Daniel',
         'Rashid Sunyaev',
         'Ratko Janev',
         'Raúl Rabadán',
         'Ravi Gomatam',
         'Ray Mackintosh',
         'Raymond Davis, Jr.',
         'Raymond Seeger',
         'Raymond T. Birge',
         'Reinhard Oehme',
         'René Antoine Ferchault de Réaumur',
         'René Descartes',
         'Revaz Dogonadze',
         'Riazuddin (physicist)',
         'Ricardo Carezani',
         'Riccardo Barbieri',
         'Riccardo Giacconi',
         'Riccardo Rattazzi',
         'Richard A. Muller',
         'Richard Arnowitt',
         'Richard C. Tolman',
         'Richard Clegg',
         'Richard Dalitz',
         'Richard E. Taylor',
         'Richard Feynman',
         'Richard H. Price',
         'Richard Keith Ellis',
         'Richard Makinson',
         'Robbert Dijkgraaf',
         'Robert Adler',
         'Robert B. Laughlin',
         'Robert B. Leighton',
         'Robert Boyle',
         'Robert Brout',
         'Robert Coleman Richardson',
         'Robert D. Richtmyer',
         'Robert Dicke',
         'Robert Döpel',
         'Robert G. Sachs',
         'Robert Hofstadter',
         'Robert Hooke',
         'Robert K. Logan',
         'Robert Marshak',
         'Robert Millikan',
         'Robert Oppenheimer',
         'Robert R. Wilson',
         'Robert S. Mulliken',
         'Robert Serber',
         'Robert von Lieben',
         'Robert W. Wood',
         'Robert Woodrow Wilson',
         'Robert Zwanzig',
         'Roger Penrose',
         'Rolf Landauer',
         'Roman Jackiw',
         'Roman U. Sexl',
         'Ronald E. McNair',
         'Ronald Ernest Aitchison',
         'Rosalind Franklin',
         'Rosalyn Yalow',
         'Roy J. Glauber',
         'Royal Prussia',
         'Ruby Payne-Scott',
         'Rudjer Josip Boscovich',
         'Rudolf Clausius',
         'Rudolf Haag',
         'Rudolf Mössbauer',
         'Rudolf Peierls',
         'Russell Alan Hulse',
         'Ryogo Kubo',
         'Sam Treiman',
         'Samuel Abraham Goudsmit',
         'Samuel C. C. Ting',
         'Samuel Goudsmit',
         'Samuel King Allison',
         'Samuel T. Durrance',
         'Samuel Tolansky',
         'Sanja Damjanović',
         'Sankar Das Sarma',
         'Satyendra Nath Bose',
         'Saul Perlmutter',
         'Savas Dimopoulos',
         'Scott Diddams',
         'Semen Altshuler',
         'Serge Haroche',
         'Serge Rudaz',
         'Sergei Tyablikov',
         'Sergei Vavilov',
         'Sergio Ferrara',
         'Serguei Krasnikov',
         'Seth Lloyd',
         'Seth Neddermeyer',
         'Sheldon Lee Glashow',
         'Shen Kuo',
         'Shiraz Minwalla',
         'Shirley Ann Jackson',
         'Shoichi Sakata',
         'Sidney Drell',
         'Sidney Redner',
         'Siméon Denis Poisson',
         'Simon Newcomb',
         'Simon Stevin',
         'Simon van der Meer',
         'Sin-Itiro Tomonaga',
         'Sir Isaac Newton',
         'Sir William Crookes',
         'Sixto González',
         'Stanislav Mikheyev',
         'Stanislaw Ulam',
         'Stanley Deser',
         'Stanley Mandelstam',
         'Stephen Gasiorowicz',
         'Stephen Hawking',
         'Stephen Hsu',
         'Stephen L. Adler',
         'Stephen Parke',
         'Stephen Paul (physicist)',
         'Stephen Wolfram',
         'Steven Chu',
         'Steven Frautschi',
         'Steven Gubser',
         'Steven Weinberg',
         'Subrahmanyan Chandrasekhar',
         'Sudhansu Datta Majumdar',
         'Sumio Iijima',
         'Susumu Okubo',
         'Swapan Chattopadhyay',
         'Sylvester James Gates',
         'T. H. Laby',
         'Tahir Hussain (physicist)',
         'Takaaki Kajita',
         'Tanya Monro',
         'Tatyana Afanasyeva',
         'Tekin Dereli',
         'Terence James Elkins',
         'Thales',
         'Thanu Padmanabhan',
         'Theodor Kaluza',
         'Theodor W. Hänsch',
         'Theodore Maiman',
         'Theodore von Kármán',
         'Thomas Corwin Mendenhall',
         'Thomas Curtright',
         'Thomas Edison',
         'Thomas H. Stix',
         'Thomas Johann Seebeck',
         'Thomas Young (scientist)',
         'Toichiro Kinoshita',
         'Tom Baehr-Jones',
         'Tom Banks (physicist)',
         'Tom W. B. Kibble',
         'Toshihide Maskawa',
         'Tsung-Dao Lee',
         'Tullio Regge',
         'Twersky',
         'Tycho Brahe',
         'Ulrike Diebold',
         'V. Balakrishnan (physicist)',
         'Val Logsdon Fitch',
         'Valentine Telegdi',
         'Valerie Gibson',
         'Valery Pokrovsky',
         'Vera Rubin',
         'Viatcheslav Mukhanov',
         'Victor Francis Hess',
         'Victor Frederick Weisskopf',
         'Victor Popov',
         'Vikram Sarabhai',
         'Viktor Ambartsumian',
         'Viktor Dilman',
         'Viktor Hambardzumyan',
         'Vilhelm Bjerknes',
         'Vitaly Ginzburg',
         'Vladimir Fock',
         'Vladimir Gribov',
         'Vlatko Vedral',
         'W.W. Hansen',
         'Walter Boas',
         'Walter Franz',
         'Walter Gerlach',
         'Walter H. Schottky',
         'Walter Heitler',
         'Walter Houser Brattain',
         'Walter Lewin',
         'Walter Marshall, Baron Marshall of Goring',
         'Walter Selke',
         'Walther Bothe',
         'Walther Kossel',
         'Walther Ritz',
         'Wander Johannes de Haas',
         'Ward Plummer',
         'Werner Heisenberg',
         'Werner Israel',
         'Werner Karl Heisenberg',
         'Wernher Von Braun',
         'Wilhelm Eduard Weber',
         'Wilhelm Röntgen',
         'Wilhelm Wien',
         'Willard Boyle',
         'Willebrord Snell',
         'Willem de Sitter',
         'Willem Hendrik Keesom',
         "Willem 's Gravesande",
         'William A. Bardeen',
         'William Alfred Fowler',
         'William Allis',
         'William Daniel Phillips',
         'William Eccles',
         'William Fuller Brown, Jr.',
         'William Gilbert (astronomer)',
         'William Henry Bragg',
         'William Lawrence Bragg',
         'William Markowitz',
         'William Prout',
         'William R. Kanne',
         'William Rowan Hamilton',
         'William Shockley',
         'William Thomson, 1st Baron Kelvin',
         'William V. Houston',
         'Willibald Peter Prasthofer',
         'Willis Lamb',
         'Willy Fischler',
         'Wojciech H. Zurek',
         'Woldemar Voigt',
         'Wolfgang Finkelnburg',
         'Wolfgang K. H. Panofsky',
         'Wolfgang Ketterle',
         'Wolfgang Paul',
         'Wolfgang Pauli',
         'Xiao-Gang Wen',
         "Yakov Borisovich Zel'dovich",
         'Yakov Frenkel',
         'Yakov Lvovich Alpert',
         'Yasha Rosenfeld',
         'Yasunori Nomura',
         'Yoichiro Nambu',
         'Yoji Totsuka',
         'Yoshinori Tokura',
         'Yulii Borisovich Khariton',
         'Yuri Feodorovich Orlov',
         "Yuval Ne'eman",
         'Zhores Ivanovich Alferov',
         'Zoltán Lajos Bay'
    ]

@pytest.fixture
def file_to_write(tmpdir):
    return tmpdir.mkdir("tmp").join("list.txt")

# %%
ipytest.clean_tests("test_get_notable_physicists*")


def test_get_notable_physicists(notable_physicists):
    assert(get_notable_physicists() == notable_physicists)


ipytest.run_pytest(filename='../../tests/test_1.0-collect-physicists.ipynb',
                   pytest_options=PYTEST_OPTIONS)

# %%
ipytest.clean_tests("test_write_list_to_file*")


def test_write_list_to_file_non_empty_list(notable_physicists, file_to_write):
    write_list_to_file(file_to_write, notable_physicists)
    with open(file_to_write, mode='r', encoding='utf-8') as list_file:
        lines = [line.rstrip() for line in list_file]
        assert(lines == notable_physicists)


def test_write_list_to_file_empty_list(file_to_write):
    write_list_to_file(file_to_write, [])
    with open(file_to_write, mode='r', encoding='utf-8') as list_file:
        lines = [line.rstrip() for line in list_file]
        assert(not lines)


ipytest.run_pytest(filename='../../tests/test_1.0-collect-physicists.ipynb',
                   pytest_options=PYTEST_OPTIONS)

# %%
# !jupyter nbconvert --ClearOutputPreprocessor.enabled=False --output-dir ../../tests/html_output --to html ../../tests/test_1.0-collect-physicists.ipynb

# %%
# !jupyter nbconvert --ClearOutputPreprocessor.enabled=True --to notebook ../../tests/test_1.0-collect-physicists.ipynb
